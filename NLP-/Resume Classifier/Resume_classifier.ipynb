# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import text
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv(r'resume_dataset_1200.csv')

# %%
df.sample(5)
# Out:
#                      Name  Age      Gender Education_Level  \
# 399         Mason Jackson   43  Non-Binary        Master's
# 183          David Wilson   21  Non-Binary             PhD
# 81           Arjun Garcia   36        Male      Bachelor's
# 299          Meera Pillai   28        Male      Bachelor's
# 630  Charlotte Srinivasan   42  Non-Binary             PhD
#
#               Field_of_Study                               Degrees  \
# 399   Electrical Engineering    Master's in Electrical Engineering
# 183      Information Systems            PhD in Information Systems
# 81    Electrical Engineering  Bachelor's in Electrical Engineering
# 299      Information Systems     Bachelor's in Information Systems
# 630  Artificial Intelligence        PhD in Artificial Intelligence
#
#                             Institute_Name  Graduation_Year  Experience_Years  \
# 399             London School of Economics             2016                 9
# ...

# %%
df.isna().sum()
# Out:
# Name                        0
# Age                         0
# Gender                      0
# Education_Level             0
# Field_of_Study              0
# Degrees                     0
# Institute_Name              0
# Graduation_Year             0
# Experience_Years            0
# Current_Job_Title         441
# Previous_Job_Titles       914
# Skills                      0
# Certifications            319
# Target_Job_Description      0
# dtype: int64

# %%
df = df.drop(columns= ['Name','Current_Job_Title','Previous_Job_Titles','Certifications'])

# %%
ohe = OneHotEncoder()
ohe.fit_transform(df['Gender'])
# Out:
#       Age      Gender Education_Level           Field_of_Study  \
# 0      30  Non-Binary        Master's            Cybersecurity
# 1      27  Non-Binary      Bachelor's  Electronics Engineering
# 2      45        Male      Bachelor's         Computer Science
# 3      28        Male        Master's   Information Technology
# 4      42  Non-Binary        Master's  Electronics Engineering
# ...   ...         ...             ...                      ...
# 1195   37      Female      Bachelor's  Supply Chain Management
# 1196   29  Non-Binary        Master's                Sociology
# 1197   45      Female         Diploma                Chemistry
# 1198   29      Female      Bachelor's                  Biology
# 1199   26  Non-Binary        Master's                Sociology
#
#                                     Degrees  \
# 0                 Master's in Cybersecurity
# 1     Bachelor's in Electronics Engineering
# 2            Bachelor's in Computer Science
# ...
