# %%
import pandas as pd

# %%
df = pd.read_csv(r'bbc-text.csv')
df.sample(3)
# Out:
#       category                                               text
# 366       tech  mobile multimedia slow to catch on there is no...
# 1403  business  glaxo aims high after profit fall glaxosmithkl...
# 796       tech  uk broadband gets speed injection broadband s ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
bow = cv.fit_transform(df['text'])

# %%
print(cv.vocabulary_)
# Out:
# {'tv': 27299, 'future': 11495, 'in': 13801, 'the': 26462, 'hands': 12561, 'of': 18726, 'viewers': 28191, 'with': 28955, 'home': 13183, 'theatre': 26464, 'systems': 26007, 'plasma': 20146, 'high': 13002, 'definition': 7862, 'tvs': 27302, 'and': 2429, 'digital': 8332, 'video': 28174, 'recorders': 21691, 'moving': 17832, 'into': 14340, 'living': 16089, 'room': 22779, 'way': 28572, 'people': 19740, 'watch': 28540, 'will': 28852, 'be': 3620, 'radically': 21317, 'different': 8316, 'five': 10875, 'years': 29260, 'time': 26665, 'that': 26454, 'is': 14510, 'according': 1650, 'to': 26730, 'an': 2395, 'expert': 10212, 'panel': 19383, 'which': 28749, 'gathered': 11644, 'at': 2994, 'annual': 2524, 'consumer': 6764, 'electronics': 9414, 'show': 24042, 'las': 15561, 'vegas': 28057, 'discuss': 8504, 'how': 13346, 'these': 26500, 'new': 18278, 'technologies': 26246, 'impact': 13703, 'one': 18837, 'our': 19052, 'favourite': 10530, 'pastimes': 19544, 'us': 27901, 'leading': 15662, 'trend': 27085, 'programmes': 20844, 'other': 19039, 'content': 6796, 'delivered': 7927, 'via': 28137, 'networks': 18258, 'through': 26588, 'cable': 5004, 'satellite': 23173, 'telecoms': 26281, 'companies': 6390, 'broadband': 4665, 'service': 23722, 'providers': 20990, 'front': 11379, 'rooms': 22780, 'portable': 20380, 'devices': 8231, 'most': 17758, 'talked': 26079, 'about': 1551, 'ces': 5519, 'has': 12684, 'been': 3706, 'personal': 19833, 'dvr': 9143, 'pvr': 21153, 'set': 23729, 'top': 26806, 'boxes': 4460, 'like': 15949, 'tivo': 26724, 'uk': 27376, 'sky': 24327, 'system': 26004, 'allow': 2219, 'record': 21687, 'store': 25345, 'play': 20163, 'pause': 19594, 'forward': 11197, 'wind': 28884, 'when': 28740, 'they': 26501, 'want': 28464, 'essentially': 9916, 'technology': 26248, 'allows': 2225, 'for': 11102, 'much': 17871, 'more': 17721, 'personalised': 19836, 'are': 2741, 'also': 2251, 'being': 3744, 'built': 4826, 'sets': 23735, 'big': 3961, 'business': 4934, 'japan': 14664, 'but': 4944, 'slower': 24426, 'take': 26057, 'off': 18730, 'europe': 9974, 'because': 3672, 'lack': 15433, 'programming': 20845, 'not': 18502, 'only': 18849, 'can': 5112, 'adverts': 1892, 'forget': 11147, 'abiding': 1532, 'by': 4980, 'network': 18255, 'channel': 5596, 'schedules': 23305, 'putting': 21148, 'together': 26744, 'their': 26471, 'own': 19254, 'la': 15416, 'carte': 5305, 'entertainment': 9746, 'some': 24635, 'worried': 29091, 'what': 28726, 'it': 14557, 'means': 17037, 'them': 26474, 'terms': 26372, 'advertising': 1891, 'revenues': 22427, 'as': 2868, 'well': 28674, 'brand': 4512, 'identity': 13568, 'viewer': 28190, 'loyalty': 16278, 'channels': 5598, 'although': 2262, 'leads': 15664, 'this': 26531, 'moment': 17639, 'concern': 6521, 'raised': 21374, 'particularly': 19493, 'growing': 12313, 'uptake': 27879, 'services': 23723, 'happens': 12595, 'here': 12930, 'today': 26737, 'we': 28581, 'see': 23558, 'nine': 18387, 'months': 17692, 'adam': 1753, 'hume': 13412, 'bbc': 3613, 'broadcast': 4667, 'futurologist': 11500, 'told': 26754, 'news': 18296, 'website': 28622, 'likes': 15959, 'there': 26490, 'no': 18414, 'issues': 14553, 'lost': 16237, 'revenue': 22426, 'yet': 29276, 'pressing': 20647, 'issue': 14549, 'commercial': 6342, 'broadcasters': 4669, 'important': 13748, 'everyone': 10039, 'talking': 26081, 'brands': 4517, 'rather': 21476, 'than': 26445, 'said': 23041, 'tim': 26662, 'hanlon': 12576, 'from': 11377, 'communications': 6378, 'firm': 10842, 'starcom': 25125, 'mediavest': 17070, 'reality': 21556, 'connections': 6653, 'anybody': 2582, 'producer': 20803, 'he': 12765, 'added': 1772, 'challenge': 5558, 'now': 18557, 'hard': 12610, 'promote': 20879, 'programme': 20840, 'so': 24554, 'choice': 5783, 'stacey': 25040, 'jolna': 14835, 'senior': 23642, 'vice': 28151, 'president': 20637, 'guide': 12358, 'group': 12306, 'find': 10775, 'simplified': 24197, 'or': 18936, 'could': 7070, 'leaf': 15666, 'out': 19058, 'google': 12066, 'book': 4325, 'search': 23493, 'engine': 9678, 'instead': 14183, 'schedul ...

# %%
print(bow[1].toarray())
# Out:
# [[0 1 0 ... 0 0 0]]

# %%
N_grms = CountVectorizer(ngram_range = (1,5))
grm = N_grms.fit_transform(df['text'])
